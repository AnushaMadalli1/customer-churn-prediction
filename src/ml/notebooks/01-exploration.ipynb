# %% [markdown]
# # 01. Exploratory Data Analysis
#
# Load and explore the customer churn dataset.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/churn.csv')  # Add your data here
df.head()

# %%
df['Churn'].value_counts(normalize=True)
